# %% [markdown]
# # Разреженный автокодировщик
#
# Вот как устроен "обычный" автокодировщик: $f(x, \omega) \rightarrow x'; \omega^* = \underset{\omega}{\operatorname{argmin}} \mathcal{L}(x', f(x, \omega))$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Разреженный автокодировщик
#
# Автокодировщики подходят для unsupervised - обучения. Привлекательно выглядит идея обучить автокодировщик на большом объеме данных, а затем использовать латентные коды $z$ как извлеченные признаки (например, при transfer learning).
#
# Как правило, размерность $z$ < размерности $x$. Но это не обязательно: можно использовать размерность $z$ большую, если наложить на нее дополнительную _регуляризацию_.
#
# # Регуляция в разреженных AE
#
# > Для регуляризации $z$ можно использовать разные "разреживающие ограничения": sparsity constraints. Мы рассмотрим применение $l_1$ и $KL$ - дивергенции.
# ## l1-регуляризация
#
# Lasso - регуляризация: $l_1 = \lambda \sum_{i=1}^k |w_i|$
# Ridge - регуляризация: $l_2 = \lambda \sum_{i=1}^k w_i^2$
#
# > Для чего их применяют?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Если мы применим такую регуляризацию к $z$, мы можем получить "разреженную" репрезентацию. То есть активной (больше определенного порога) в ней будет небольшая часть нейронов.
#
# Это позволит получать такие репрезентации, на которых _проще_ обучаться - т.е. более полезные для нас. Есть и другие интересные свойства, о которых мы поговорим позже.
#
# ## KL-дивергенция
#
# Сначала - математическое ожидание для дискретного случая: $\mathcal{X} = \{x_1, x_2, \dots, x_n\}$; вероятности заданы как $P(x_i) = p_i$. Математическое ожидание тогда $\mathbb{E}[X] = \sum_{x \in \mathcal{X}} x \cdot P(x)$.
#
# KL-дивергенция _между двумя распределениями над одним и тем же вероятностным пространством_ записывается как $D_{KL}(P||Q)$ и равна
#
# $$D_{KL}(P||Q) = \sum_{x \in \mathcal{X}} P(x)\log{\bigg(\frac{P(X)}{Q(X)}\bigg)}$$ - или математическое ожидание по $P(X)$ разности логарифмов $P(X)$ и $Q(X)$:
#
# ![alt text](https://upload.wikimedia.org/wikipedia/commons/a/a8/KL-Gauss-Example.png)
#
# > Как применить KL-дивергенцию для разреживания $z$?
#
# * Задать распределение бернулии $X$ c заданной вероятностью получить $1$, равной $\hat{\rho}$. Его мат. ожидание $\mathbb{E}[X] = \hat{\rho}$.
# * Представить, что нейроны в $z$ пытаются "приблизить" собой распределение Бернулии $\rho$. Т.е. они независимо (что не совсем верно) преодолевают порог активации и в таком случае считаются $"1"$.
# * Начать считать KL между распределениями $\rho$ и $\hat{\rho}$ и добавить его как регуляризацию к модели.
#
# Тогда
#
# $$D_{KL}(\rho||X) = \sum_i \rho_i \log{\bigg(\frac{\rho_i}{x_i}\bigg)}$$
#
# И в данном случае можно заменить все $x_i$ на $\mathbb{E}[X] = \hat{\rho}$, получим
#
# $$D_{KL}(\rho||X) = \sum_i \rho_i \log{\bigg(\frac{\rho_i}{\hat{\rho}}\bigg)}$$
#
# Эту формулу мы будем использовать для регуляризации модели.

# %% [markdown]
# # Практика

# %%
from typing import Union, Mapping, Sized

import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras.datasets import mnist


def load_mnist(shape):
    """
    Загрузка и предобработка датасета MNIST
    :param shape: целевая размерность датасета
    :return: подготовленный датасет
    """
    (X_train, Y_train), (X_test, Y_test) = mnist.load_data()
    X_train = X_train / 255.
    X_test = X_test / 255.
    X_train = X_train.reshape(-1, shape)
    X_test = X_test.reshape(-1, shape)
    return (X_train, Y_train), (X_test, Y_test)


def get_sample(values, sample_size):
    """
    Извлекает заданное количество случайных сэмплов из дадасета случайным образом
    :param values: множество значений (данные)
    :param sample_size: количество значений в сэмпле
    :return: выбранное подмножетсво значений
    """
    arange = np.arange(len(values))
    idx = np.random.choice(arange, sample_size)
    return values[idx]


def get_one_item_of_each_class(values, labels):
    """
    Извлекает по одному случайному изображению для каждого из классов MNIST,
    возвращает в отсортированном порядке.
    :param values: множество значений (данные)
    :param labels: метки для данных
    :return: отсортированный по меткам набор изображений
    """
    output = []
    label_set = []
    idx = np.arange(len(values))
    np.random.shuffle(idx)
    values = values[idx]
    labels = labels[idx]
    for (val, label) in zip(values, labels):
        if label not in label_set:
            label_set.append(label)
            output.append(val)
            if len(label_set) == 10:
                break

    sorted_labels = np.argsort(label_set)
    return np.array(output)[sorted_labels]


def train_val_split(x, train_size: float):
    """
    Разделяет выборку на обучающую и валидационную.
    :param x: выборка для разделения
    :param train_size: float в диапазоне [0, 1] - размер обучающей выборки
    :return: пара (обучающая выборка, валидационная выборка)
    """
    length = len(x)
    idx = np.arange(length)
    np.random.shuffle(idx)
    train_idx = idx[:int(length * train_size)]
    val_idx = idx[int(length * train_size):]
    train = x[train_idx]
    val = x[val_idx]
    return train, val


def reconstruct_from_top_k(encoder: Model, decoder: Model, k: int,
                           images: np.array) -> np.array:
    """
    Реконструирует изображения из k наибольших активаций в латентном слое.
    :param encoder: обученный энкодер
    :param decoder: обученный декодер
    :param k: количество нейронов, котоыре не будут обнулены
    :param images: изображения для реконструкции
    :return: реконструированные изображения
    """
    latent = encoder.predict(images)
    for i in range(len(images)):
        argsort = np.argsort(latent[i])
        nullify = argsort[:-k]
        latent[i, nullify] = 0
    reconstructed = decoder.predict(latent)
    return reconstructed


def plot_reconstructed_from_top_k(images_list: Union[Mapping, Sized], 
                                  save_to: str, image_shape, n_active: int,
                                  show=False):
    """
    Реконструирует изображение, обнуляя k наименьших активаций в латентном слое
    :param images_list: набор изображений для ркконструкции
    :param save_to: путь для сохранения файла
    :param image_shape: размерность изображения
    :param n_active: количество активных нейронов
    :return: None
    """
    _, images = next(iter(images_list.items()))
    f, axes = plt.subplots(len(images_list), len(images), sharey=True)
    image_shape = [-1] + list(image_shape)

    for idx, (path_to_model, images) in enumerate(images_list.items()):
        images = images.reshape(*image_shape)
        for j, img in enumerate(images):
            axes[idx, j].matshow(img, cmap='gray')
            axes[idx, j].set_xticks([])
            axes[idx, j].set_yticks([])

            if j == 0:
                axes[idx, j].set_ylabel(f'{path_to_model.split("/")[-1]}',
                                        rotation=90,
                                        size=8)

    f.suptitle(f'Reconstructed from top {n_active} neurons from hidden layer')
    if show:
      plt.show()
    else:
      f.savefig(save_to)
      plt.close(f)

def plot_latent_unit_activation(decoder: tf.keras.Model, latent_codes, save_to,
                                image_shape, show=False):
    """
    Реконструирует и созраняет изображение по активациям латентного слоя
    :param decoder: обученный декодер
    :param latent_codes: батч латентных представлений (возможно, сгенерированный)
    :param save_to: путь изображения
    :param image_shape: размерность реконструированного изображения
    :return: None
    """
    reconstructed = decoder.predict(latent_codes)
    f, axes = plt.subplots(8, 8, sharey=True)

    image_shape = [-1] + list(image_shape)
    reconstructed = reconstructed.reshape(*image_shape)

    for i in range(8):
        for j in range(8):
            axes[i, j].matshow(reconstructed[i * 8 + j], cmap='gray')
            axes[i, j].set_xticks([])
            axes[i, j].set_yticks([])

    if show:
      plt.show()
    else:
      f.savefig(save_to)
      plt.close(f)

def plot_reconstruction(autoencoder: tf.keras.Model, images, save_to, 
                        image_shape, show=False):
    """
    Реконструирует и созраняет изображение по активациям латентного слоя
    :param autoencoder: обученный автокодировщик
    :param images: батч изображений
    :param save_to: путь изображения
    :param image_shape: размерность реконструированного изображения
    :return: None
    """
    reconstructed = autoencoder.predict(images)
    f, axes = plt.subplots(2, len(images), sharey=True)

    image_shape = [-1] + list(image_shape)
    reconstructed = reconstructed.reshape(*image_shape)
    images = images.reshape(*image_shape)

    for idx, (img, rec) in enumerate(zip(images, reconstructed)):
        title_opts = dict(y=1.1, rotation=30, size=8)
        axes[0, idx].matshow(img)
        axes[0, idx].set_title(f"Original {idx}", **title_opts)
        axes[1, idx].matshow(rec)
        axes[1, idx].set_title(f"Reconstructed {idx}", **title_opts)
        axes[0, idx].set_xticks([])
        axes[0, idx].set_yticks([])
        axes[1, idx].set_xticks([])
        axes[1, idx].set_yticks([])

    if show:
      plt.show()
    else:
      f.savefig(save_to)
      plt.close(f)

# %%
# import utils

# %% [markdown]
# # Код для создания модели и регуляризаторы активации

# %%
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input

from tensorflow.keras.regularizers import Regularizer
import tensorflow.keras.backend as K

# %%
Dense(10)

# %%
tf.keras.layers.InputLayer()

# %%
def create_model(input_size: int,
                 latent_size: int,
                 activity_regularizer: Regularizer) -> Model:
    """
    Функция для создания автокодировщика.
    :param input_size: размерность входного вектора.
    :param latent_size: размерность латентного пространства.
    :param activity_regularizer: регуляризатор активации нейронов латентного слоя.
    :return: tf.keras.Model
    """
    output_size = input_size
    x = Input(shape=(input_size,), name='input')
    z = Dense(latent_size,
              activation='sigmoid',
              activity_regularizer=activity_regularizer,
              name='encoder')(x)
    r = Dense(output_size, activation='sigmoid', name='decoder')(z)
    return Model(x, r)


def load_encoder_decoder_pair(
    autoencoder: Model, path_to_weights: str = None) -> (Model, Model):
    """
    Создает из автокодировщика энкодер и декодер, используя веса модели.
    :param autoencoder: автокодировщик
    :param path_to_weights: путь до весов модели
    :return: пара (энкодер, декодер)
    """
    if path_to_weights is not None:
      autoencoder.load_weights(path_to_weights)

    encoder_layer = autoencoder.get_layer('encoder')
    decoder_layer = autoencoder.get_layer('decoder')
    input_tensor = autoencoder.get_layer('input').input

    latent_input = Input(shape=encoder_layer.output_shape[-1],
                         name='latent_input')

    z = encoder_layer(input_tensor)
    reconstructed = decoder_layer(latent_input)

    decoder = Model(latent_input, reconstructed)
    encoder = Model(input_tensor, z)
    return encoder, decoder


# For nightly build.
# More: https://www.tensorflow.org/api_docs/python/tf/keras/regularizers/Regularizer
# @tf.keras.utils.register_keras_serializable(package='Custom', name='KL')
class KLRegularizer(Regularizer):
    """
    KL - регуляризатор
    """
    def __init__(self, rho, alpha=1, size_average=False):
        """
        Инициализация регуляризатора с заданным ро.
        :param rho: целевая вероятность активации нейрона.
        :param size_average: усреднение лосса
        """
        self.size_average = size_average
        self.rho = rho
        self.alpha = alpha

    def __call__(self, data_rho):
        """
        D_KL(P||Q) = sum(p*log(p/q)) = -sum(p*log(q/p)) = -p*log(q/p) - (1-p)log((1-q)/(1-p))
        """
        eps = K.epsilon()  # ближайшее к нулю значение типа float
        dkl = (- self.rho       * tf.math.log(eps + data_rho       / (self.rho + eps))
               - (1 - self.rho) * tf.math.log(eps + (1 - data_rho) / (1 - self.rho + eps)))
        if self.size_average:
            _rho_loss = tf.reduce_mean(dkl)
        else:
            _rho_loss = tf.reduce_sum(dkl)
        return _rho_loss * self.alpha

    def get_config(self):
        return {'rho': float(self.rho),
                'alpha': float(self.alpha),
                'size_average': self.size_average}


def make_encoder(model: Model) -> Model:
    """
    "Извлечение" энкодера из автокодировщика.
    :param model: автокодировщик
    :return: извлеченный энкодер
    """
    input = model.get_layer('input')
    encoder = model.get_layer('encoder')
    return Model(input.input, encoder.output)

# %% [markdown]
# # Обучение моделей

# %% [markdown]
# ## Обычный автоэнкодер

# %%
import os
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
# from utils import load_mnist, get_sample, train_val_split, plot_reconstruction

# %%
images = 'images'
models = 'models'
os.makedirs(images, exist_ok=True)
os.makedirs(models, exist_ok=True)

save_to = os.path.join(images, 'reconstruction_vanilla.png')
model_path = os.path.join(models, 'ae_vanilla.h5')
log_dir = 'tb_logs/vanilla'
image_shape = (28, 28)
num_classes = 10
input_size = 784
latent_size = 64
output_size = 784
sample_size = 6

"""
Создание и обучение автоэкодера без регуляризации.
"""
autoencoder = create_model(input_size, latent_size, activity_regularizer=None)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

(X_train, y_train), (X_test, y_test) = load_mnist(input_size)
X, X_val = train_val_split(X_train, 0.8)

autoencoder.fit(X, X,
                validation_data=(X_val, X_val),
                epochs=200,
                batch_size=64,
                callbacks=[TensorBoard(log_dir=log_dir, histogram_freq=1),
                           ModelCheckpoint(model_path, str='val_loss', save_best_only=True),
                           EarlyStopping(patience=5, min_delta=0.0001),
                           ]
                )

sample = get_sample(X_test, sample_size)
plot_reconstruction(autoencoder, sample, save_to, (28, 28), show=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Epoch 1/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2760 - val_loss: 0.2533
# Epoch 2/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2282 - val_loss: 0.2075
# Epoch 3/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1926 - val_loss: 0.1806
# Epoch 4/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1701 - val_loss: 0.1619
# Epoch 5/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1542 - val_loss: 0.1487
# Epoch 6/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1425 - val_loss: 0.1384
# Epoch 7/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1332 - val_loss: 0.1303
# Epoch 8/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1262 - val_loss: 0.1244
# Epoch 9/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1212 - val_loss: 0.1201
# Epoch 10/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1175 - val_loss: 0.1168
# Epoch 11/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1145 - val_loss: 0.1140
# Epoch 12/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1115 - val_loss: 0.1108
# Epoch 13/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1077 - val_loss: 0.1065
# Epoch 14/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1034 - val_loss: 0.1021
# Epoch 15/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0987 - val_loss: 0.0973
# Epoch 16/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0942 - val_loss: 0.0930
# Epoch 17/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0904 - val_loss: 0.0897
# Epoch 18/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0875 - val_loss: 0.0872
# Epoch 19/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0853 - val_loss: 0.0852
# Epoch 20/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0837 - val_loss: 0.0838
# Epoch 21/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0825 - val_loss: 0.0828
# Epoch 22/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0815 - val_loss: 0.0819
# Epoch 23/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0807 - val_loss: 0.0813
# Epoch 24/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0801 - val_loss: 0.0807
# Epoch 25/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0796 - val_loss: 0.0802
# Epoch 26/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0791 - val_loss: 0.0798
# Epoch 27/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0787 - val_loss: 0.0794
# Epoch 28/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0784 - val_loss: 0.0791
# Epoch 29/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0781 - val_loss: 0.0788
# Epoch 30/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0778 - val_loss: 0.0786
# Epoch 31/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0775 - val_loss: 0.0783
# Epoch 32/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0773 - val_loss: 0.0780
# Epoch 33/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0771 - val_loss: 0.0779
# Epoch 34/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0769 - val_loss: 0.0777
# Epoch 35/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0767 - val_loss: 0.0775
# Epoch 36/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0766 - val_loss: 0.0774
# Epoch 37/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0764 - val_loss: 0.0772
# Epoch 38/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0763 - val_loss: 0.0771
# Epoch 39/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0762 - val_loss: 0.0769
# Epoch 40/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0760 - val_loss: 0.0769
# Epoch 41/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0759 - val_loss: 0.0768
# Epoch 42/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0758 - val_loss: 0.0766
# Epoch 43/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0757 - val_loss: 0.0766
# Epoch 44/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0756 - val_loss: 0.0764
# Epoch 45/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0755 - val_loss: 0.0764
# Epoch 46/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0755 - val_loss: 0.0763
# Epoch 47/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0754 - val_loss: 0.0762
# Epoch 48/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0753 - val_loss: 0.0761
# Epoch 49/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0753 - val_loss: 0.0761
# Epoch 50/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0752 - val_loss: 0.0760
# Epoch 51/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0751 - val_loss: 0.0759
# Epoch 52/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0751 - val_loss: 0.0759
# Epoch 53/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0750 - val_loss: 0.0759
# Epoch 54/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0750 - val_loss: 0.0758
# Epoch 55/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0749 - val_loss: 0.0757
# Epoch 56/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0749 - val_loss: 0.0757
# Epoch 57/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0748 - val_loss: 0.0757
# Epoch 58/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0748 - val_loss: 0.0757
# Epoch 59/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0747 - val_loss: 0.0756
# Epoch 60/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0747 - val_loss: 0.0756
# Epoch 61/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0746 - val_loss: 0.0755
# Epoch 62/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0746 - val_loss: 0.0754
# Epoch 63/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0746 - val_loss: 0.0754
# Epoch 64/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0745 - val_loss: 0.0755
# Epoch 65/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0745 - val_loss: 0.0754
# Epoch 66/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0745 - val_loss: 0.0753
# Epoch 67/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0744 - val_loss: 0.0753
# Epoch 68/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0744 - val_loss: 0.0753
# Epoch 69/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0744 - val_loss: 0.0752
# Epoch 70/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0743 - val_loss: 0.0752
# Epoch 71/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0743 - val_loss: 0.0752
# Epoch 72/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0743 - val_loss: 0.0752
# Epoch 73/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0743 - val_loss: 0.0751
# Epoch 74/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0742 - val_loss: 0.0752
# Epoch 75/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0742 - val_loss: 0.0751
# Epoch 76/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0742 - val_loss: 0.0751
# Epoch 77/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0742 - val_loss: 0.0750
# Epoch 78/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0741 - val_loss: 0.0750
# Epoch 79/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0741 - val_loss: 0.0750
# Epoch 80/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0741 - val_loss: 0.0750
# Epoch 81/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0741 - val_loss: 0.0750
# Epoch 82/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0741 - val_loss: 0.0750
# Epoch 83/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0740 - val_loss: 0.0750
# Epoch 84/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0740 - val_loss: 0.0749

# %% [markdown]
# ## l1 activity regularizer

# %%
from tensorflow.keras.regularizers import l1

# %%
images = 'images'
models = 'models'
os.makedirs(images, exist_ok=True)
os.makedirs(models, exist_ok=True)

save_to = os.path.join(images, 'reconstruction_l1.png')
model_path = os.path.join(models, 'ae_l1.h5')
log_dir = 'tb_logs/l1'
image_shape = (28, 28)
num_classes = 10
input_size = 784
latent_size = 64
output_size = 784
sample_size = 6

"""
Обучение разреженного автоэкодера с l1-регуляризацией.
"""
autoencoder = create_model(input_size, latent_size, l1(0.02))
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

(X_train, y_train), (X_test, y_test) = load_mnist(input_size)
X, X_val = train_val_split(X_train, 0.8)

autoencoder.fit(X, X,
                validation_data=(X_val, X_val),
                epochs=200,
                batch_size=64,
                callbacks=[TensorBoard(log_dir=log_dir, histogram_freq=1),
                           ModelCheckpoint(model_path, str='val_loss', save_best_only=True),
                           EarlyStopping(patience=5, min_delta=0.0001)
                           ]
                )

sample = get_sample(X_test, sample_size)
plot_reconstruction(autoencoder, sample, save_to, (28, 28), show=True)
# Out:
# Epoch 1/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.5131 - val_loss: 0.3596
# Epoch 2/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3381 - val_loss: 0.3213
# Epoch 3/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3084 - val_loss: 0.2953
# Epoch 4/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2870 - val_loss: 0.2788
# Epoch 5/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2704 - val_loss: 0.2631
# Epoch 6/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2575 - val_loss: 0.2526
# Epoch 7/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2486 - val_loss: 0.2451
# Epoch 8/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2422 - val_loss: 0.2395
# Epoch 9/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2372 - val_loss: 0.2352
# Epoch 10/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2333 - val_loss: 0.2316
# Epoch 11/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2301 - val_loss: 0.2287
# Epoch 12/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2274 - val_loss: 0.2262
# Epoch 13/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2251 - val_loss: 0.2240
# Epoch 14/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2231 - val_loss: 0.2222
# Epoch 15/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2214 - val_loss: 0.2206
# Epoch 16/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2199 - val_loss: 0.2192
# Epoch 17/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2185 - val_loss: 0.2179
# Epoch 18/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2173 - val_loss: 0.2168
# Epoch 19/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2162 - val_loss: 0.2157
# Epoch 20/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2153 - val_loss: 0.2148
# Epoch 21/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2144 - val_loss: 0.2139
# Epoch 22/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2135 - val_loss: 0.2131
# Epoch 23/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2128 - val_loss: 0.2124
# Epoch 24/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2121 - val_loss: 0.2118
# Epoch 25/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2114 - val_loss: 0.2106
# Epoch 26/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2095 - val_loss: 0.2086
# Epoch 27/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2079 - val_loss: 0.2072
# Epoch 28/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2067 - val_loss: 0.2063
# Epoch 29/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2058 - val_loss: 0.2054
# Epoch 30/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2051 - val_loss: 0.2047
# Epoch 31/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2044 - val_loss: 0.2042
# Epoch 32/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2038 - val_loss: 0.2036
# Epoch 33/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2033 - val_loss: 0.2030
# Epoch 34/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2028 - val_loss: 0.2025
# Epoch 35/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2023 - val_loss: 0.2020
# Epoch 36/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2018 - val_loss: 0.2016
# Epoch 37/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2014 - val_loss: 0.2012
# Epoch 38/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2010 - val_loss: 0.2009
# Epoch 39/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2006 - val_loss: 0.2005
# Epoch 40/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2002 - val_loss: 0.2001
# Epoch 41/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1999 - val_loss: 0.1998
# Epoch 42/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1995 - val_loss: 0.1994
# Epoch 43/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1992 - val_loss: 0.1991
# Epoch 44/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1989 - val_loss: 0.1988
# Epoch 45/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1987 - val_loss: 0.1986
# Epoch 46/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1984 - val_loss: 0.1983
# Epoch 47/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1981 - val_loss: 0.1980
# Epoch 48/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1978 - val_loss: 0.1978
# Epoch 49/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1976 - val_loss: 0.1975
# Epoch 50/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1973 - val_loss: 0.1973
# Epoch 51/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1971 - val_loss: 0.1970
# Epoch 52/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1969 - val_loss: 0.1968
# Epoch 53/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1967 - val_loss: 0.1967
# Epoch 54/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1965 - val_loss: 0.1964
# Epoch 55/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1963 - val_loss: 0.1961
# Epoch 56/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1961 - val_loss: 0.1960
# Epoch 57/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1959 - val_loss: 0.1958
# Epoch 58/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1957 - val_loss: 0.1956
# Epoch 59/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1955 - val_loss: 0.1954
# Epoch 60/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1953 - val_loss: 0.1953
# Epoch 61/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1952 - val_loss: 0.1951
# Epoch 62/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1950 - val_loss: 0.1949
# Epoch 63/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1948 - val_loss: 0.1948
# Epoch 64/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1947 - val_loss: 0.1946
# Epoch 65/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1945 - val_loss: 0.1944
# Epoch 66/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1944 - val_loss: 0.1943
# Epoch 67/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1942 - val_loss: 0.1941
# Epoch 68/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1941 - val_loss: 0.1940
# Epoch 69/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1939 - val_loss: 0.1939
# Epoch 70/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1938 - val_loss: 0.1938
# Epoch 71/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1937 - val_loss: 0.1936
# Epoch 72/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1935 - val_loss: 0.1935
# Epoch 73/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1934 - val_loss: 0.1934
# Epoch 74/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1933 - val_loss: 0.1935
# Epoch 75/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1932 - val_loss: 0.1931
# Epoch 76/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1930 - val_loss: 0.1930
# Epoch 77/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1929 - val_loss: 0.1929
# Epoch 78/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1928 - val_loss: 0.1928
# Epoch 79/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1927 - val_loss: 0.1926
# Epoch 80/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1926 - val_loss: 0.1925
# Epoch 81/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1925 - val_loss: 0.1925
# Epoch 82/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1924 - val_loss: 0.1925
# Epoch 83/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1923 - val_loss: 0.1923
# Epoch 84/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1922 - val_loss: 0.1921
# Epoch 85/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1921 - val_loss: 0.1920
# Epoch 86/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1920 - val_loss: 0.1919
# Epoch 87/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1919 - val_loss: 0.1919
# Epoch 88/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1918 - val_loss: 0.1918
# Epoch 89/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1917 - val_loss: 0.1916
# Epoch 90/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1916 - val_loss: 0.1916
# Epoch 91/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1915 - val_loss: 0.1915
# Epoch 92/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1914 - val_loss: 0.1914
# Epoch 93/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1913 - val_loss: 0.1913
# Epoch 94/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1913 - val_loss: 0.1912
# Epoch 95/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1912 - val_loss: 0.1911
# Epoch 96/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1911 - val_loss: 0.1911
# Epoch 97/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1910 - val_loss: 0.1909
# Epoch 98/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1909 - val_loss: 0.1909
# Epoch 99/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1909 - val_loss: 0.1908
# Epoch 100/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1908 - val_loss: 0.1907
# Epoch 101/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1907 - val_loss: 0.1908
# Epoch 102/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1906 - val_loss: 0.1906
# Epoch 103/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1906 - val_loss: 0.1905
# Epoch 104/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1905 - val_loss: 0.1905
# Epoch 105/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1904 - val_loss: 0.1904
# Epoch 106/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1903 - val_loss: 0.1903
# Epoch 107/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1903 - val_loss: 0.1902
# Epoch 108/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1902 - val_loss: 0.1902
# Epoch 109/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1901 - val_loss: 0.1902
# Epoch 110/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1901 - val_loss: 0.1901
# Epoch 111/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1900 - val_loss: 0.1900
# Epoch 112/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1899 - val_loss: 0.1899
# Epoch 113/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1899 - val_loss: 0.1899
# Epoch 114/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1898 - val_loss: 0.1898
# Epoch 115/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1898 - val_loss: 0.1897
# Epoch 116/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1897 - val_loss: 0.1896
# Epoch 117/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1896 - val_loss: 0.1896
# Epoch 118/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1896 - val_loss: 0.1896
# Epoch 119/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1895 - val_loss: 0.1895
# Epoch 120/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1895 - val_loss: 0.1895
# Epoch 121/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1894 - val_loss: 0.1894
# Epoch 122/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1894 - val_loss: 0.1893
# Epoch 123/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1893 - val_loss: 0.1893
# Epoch 124/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1892 - val_loss: 0.1892
# Epoch 125/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1892 - val_loss: 0.1891
# Epoch 126/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1891 - val_loss: 0.1891
# Epoch 127/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1891 - val_loss: 0.1890
# Epoch 128/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1890 - val_loss: 0.1890
# Epoch 129/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1890 - val_loss: 0.1890
# Epoch 130/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1889 - val_loss: 0.1889
# Epoch 131/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1889 - val_loss: 0.1888
# Epoch 132/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1888 - val_loss: 0.1889
# Epoch 133/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1888 - val_loss: 0.1888
# Epoch 134/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1887 - val_loss: 0.1887
# Epoch 135/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1887 - val_loss: 0.1887
# Epoch 136/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1886 - val_loss: 0.1887
# Epoch 137/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1886 - val_loss: 0.1886
# Epoch 138/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1885 - val_loss: 0.1885
# Epoch 139/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1885 - val_loss: 0.1885
# Epoch 140/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1884 - val_loss: 0.1885
# Epoch 141/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1884 - val_loss: 0.1884
# Epoch 142/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1884 - val_loss: 0.1884
# Epoch 143/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1883 - val_loss: 0.1883
# Epoch 144/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1883 - val_loss: 0.1882
# Epoch 145/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1882 - val_loss: 0.1883
# Epoch 146/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1882 - val_loss: 0.1882
# Epoch 147/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1881 - val_loss: 0.1881
# Epoch 148/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1881 - val_loss: 0.1881
# Epoch 149/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1881 - val_loss: 0.1880
# Epoch 150/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1880 - val_loss: 0.1880
# Epoch 151/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1880 - val_loss: 0.1880
# Epoch 152/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1879 - val_loss: 0.1880
# Epoch 153/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1879 - val_loss: 0.1879
# Epoch 154/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1879 - val_loss: 0.1878
# Epoch 155/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1878 - val_loss: 0.1878
# Epoch 156/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1878 - val_loss: 0.1878
# Epoch 157/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1877 - val_loss: 0.1878
# Epoch 158/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1877 - val_loss: 0.1877
# Epoch 159/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1877 - val_loss: 0.1877
# Epoch 160/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1876 - val_loss: 0.1876
# Epoch 161/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1876 - val_loss: 0.1877
# Epoch 162/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1876 - val_loss: 0.1876
# Epoch 163/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1875 - val_loss: 0.1875
# Epoch 164/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1875 - val_loss: 0.1875
# Epoch 165/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1875 - val_loss: 0.1875
# Epoch 166/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1874 - val_loss: 0.1874
# Epoch 167/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1874 - val_loss: 0.1874
# Epoch 168/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1874 - val_loss: 0.1873
# Epoch 169/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1873 - val_loss: 0.1873
# Epoch 170/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1873 - val_loss: 0.1873
# Epoch 171/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1872 - val_loss: 0.1872
# Epoch 172/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1872 - val_loss: 0.1872
# Epoch 173/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1872 - val_loss: 0.1872
# Epoch 174/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1872 - val_loss: 0.1872
# Epoch 175/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1871 - val_loss: 0.1872
# Epoch 176/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1871 - val_loss: 0.1871
# Epoch 177/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1871 - val_loss: 0.1871
# Epoch 178/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1870 - val_loss: 0.1871
# Epoch 179/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1870 - val_loss: 0.1870
# Epoch 180/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1869 - val_loss: 0.1870
# Epoch 181/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1869 - val_loss: 0.1870

# %% [markdown]
# # KL - регуляризация

# %%
images = 'images'
models = 'models'
os.makedirs(images, exist_ok=True)
os.makedirs(models, exist_ok=True)

save_to = os.path.join(images, 'reconstruction_kl.png')
model_path = os.path.join(models, 'ae_kl.h5')
log_dir = 'tb_logs/kl'
image_shape = (28, 28)
num_classes = 10
input_size = 784
latent_size = 64
output_size = 784
sample_size = 6

"""
Обучение разреженного автоэкодера с KL-регуляризацией.
"""
autoencoder = create_model(input_size, latent_size, KLRegularizer(0.001, alpha=10))
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

(X_train, y_train), (X_test, y_test) = load_mnist(input_size)
X, X_val = train_val_split(X_train, 0.8)

autoencoder.fit(X, X,
                validation_data=(X_val, X_val),
                epochs=200,
                batch_size=64,
                callbacks=[TensorBoard(log_dir=log_dir, histogram_freq=1),
                            ModelCheckpoint(model_path, str='val_loss',
                                            save_best_only=True,
                                            save_weights_only=True),
                            # EarlyStopping(patience=5, min_delta=0.0001)
                            ]
                )

sample = get_sample(X_test, sample_size)
plot_reconstruction(autoencoder, sample, save_to, (28, 28), show=True)
# Out:
# Epoch 1/200
# 750/750 [==============================] - 3s 4ms/step - loss: 14.1744 - val_loss: 2.0673
# Epoch 2/200
# 750/750 [==============================] - 3s 4ms/step - loss: 1.7907 - val_loss: 1.5823
# Epoch 3/200
# 750/750 [==============================] - 3s 4ms/step - loss: 1.5048 - val_loss: 1.4132
# Epoch 4/200
# 750/750 [==============================] - 3s 4ms/step - loss: 1.3697 - val_loss: 1.3192
# Epoch 5/200
# 750/750 [==============================] - 3s 4ms/step - loss: 1.2894 - val_loss: 1.2589
# Epoch 6/200
# 750/750 [==============================] - 3s 4ms/step - loss: 1.2332 - val_loss: 1.2119
# Epoch 7/200
# 750/750 [==============================] - 3s 4ms/step - loss: 1.1848 - val_loss: 1.1687
# Epoch 8/200
# 750/750 [==============================] - 3s 4ms/step - loss: 1.1364 - val_loss: 1.1195
# Epoch 9/200
# 750/750 [==============================] - 3s 4ms/step - loss: 1.0837 - val_loss: 1.0668
# Epoch 10/200
# 750/750 [==============================] - 3s 4ms/step - loss: 1.0250 - val_loss: 1.0042
# Epoch 11/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.9569 - val_loss: 0.9362
# Epoch 12/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.8815 - val_loss: 0.8524
# Epoch 13/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.8001 - val_loss: 0.7689
# Epoch 14/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.7160 - val_loss: 0.6880
# Epoch 15/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.6351 - val_loss: 0.6031
# Epoch 16/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.5587 - val_loss: 0.5318
# Epoch 17/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4912 - val_loss: 0.4657
# Epoch 18/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4324 - val_loss: 0.4097
# Epoch 19/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3833 - val_loss: 0.3644
# Epoch 20/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3439 - val_loss: 0.3289
# Epoch 21/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3138 - val_loss: 0.3030
# Epoch 22/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2922 - val_loss: 0.2845
# Epoch 23/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2779 - val_loss: 0.2730
# Epoch 24/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2695 - val_loss: 0.2668
# Epoch 25/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2653 - val_loss: 0.2640
# Epoch 26/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2636 - val_loss: 0.2630
# Epoch 27/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2631 - val_loss: 0.2628
# Epoch 28/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 29/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 30/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 31/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 32/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 33/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 34/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 35/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 36/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 37/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 38/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 39/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 40/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 41/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 42/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 43/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 44/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 45/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 46/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 47/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 48/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 49/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 50/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 51/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 52/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 53/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 54/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 55/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 56/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 57/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 58/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 59/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 60/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 61/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 62/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 63/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 64/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 65/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 66/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 67/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 68/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 69/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 70/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 71/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 72/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 73/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 74/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 75/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 76/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 77/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 78/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 79/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 80/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 81/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 82/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 83/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 84/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 85/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 86/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 87/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 88/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 89/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 90/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 91/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 92/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 93/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 94/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 95/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 96/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 97/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 98/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 99/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 100/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 101/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 102/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 103/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 104/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 105/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 106/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 107/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 108/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 109/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 110/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 111/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 112/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 113/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 114/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 115/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 116/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 117/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 118/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 119/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 120/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 121/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 122/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 123/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 124/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 125/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 126/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 127/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 128/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 129/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 130/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 131/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 132/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 133/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 134/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 135/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 136/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 137/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 138/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 139/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 140/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 141/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 142/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 143/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 144/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 145/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 146/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 147/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 148/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 149/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 150/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 151/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 152/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 153/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 154/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 155/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 156/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 157/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 158/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 159/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 160/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 161/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 162/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 163/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 164/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 165/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 166/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 167/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 168/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 169/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 170/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 171/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 172/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 173/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 174/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 175/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 176/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 177/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 178/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 179/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 180/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 181/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 182/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 183/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 184/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 185/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 186/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 187/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 188/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 189/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 190/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 191/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 192/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 193/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 194/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 195/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 196/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 197/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 198/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 199/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 200/200
# 750/750 [==============================] - 3s 4ms/step - loss: 0.2628 - val_loss: 0.2626

# %%
plot_reconstruction(autoencoder, sample, save_to, (28, 28), show=True)

# %% [markdown]
# # Сравнение моделей

# %% [markdown]
# ## Распределения активаций разных моделей

# %%
"""
Сравнение распределений активации нейронов в латентном слое.
"""
model_kl = create_model(input_size, latent_size, KLRegularizer(0.02))
model_kl.load_weights('models/ae_kl.h5')
model_vanilla = tf.keras.models.load_model('models/ae_vanilla.h5')
model_l1 = tf.keras.models.load_model('models/ae_l1.h5')

models = {'vanilla': model_vanilla, 'l1': model_l1, 'kl': model_kl}
models = {k: make_encoder(m) for k, m in models.items()}

(X_train, y_train), (X_test, y_test) = load_mnist(input_size)

for directory, model in models.items():
    values = model.predict(X_test)
    values = values.mean(axis=0)
    plt.hist(values, bins=25, alpha=0.5,
             label=directory, stacked=True,
             density=True, )
plt.ylim(0, 300)
plt.xlim(-0.1, 1.1)
plt.legend(loc='upper right')
plt.savefig('images/hidden_activations.png')

# %% [markdown]
# ## Создание изображения по one-hot вектору активации

# %%
autoencoder = create_model(input_size, latent_size, activity_regularizer=None)
_, decoder = load_encoder_decoder_pair(autoencoder, 'models/ae_l1.h5')

# %%
"""
Сохраняет рекоструированные изображения по одному на каждый активный нейрон.  
"""
latent_codes = np.eye(64)
plot_latent_unit_activation(decoder, latent_codes, 
                            'images/generated_images_l1.png', image_shape,
                            show=True)

# %% [markdown]
# ## Реконструкция по top-k активаций

# %%
"""
Скрипт строит графики с реконструкцией по k максимальным активациям 
латентного слоя.
"""
autoencoder = create_model(input_size, latent_size, None)
(X_train, y_train), (X_test, y_test) = load_mnist(input_size)
sample = get_one_item_of_each_class(X_test, y_test)
k_active_neurons = (4, 8, 16, 32, 64)

for active_neurons in k_active_neurons:
    image_map = {'original': sample}
    for path in ('models/ae_l1.h5', 'models/ae_kl.h5', 'models/ae_vanilla.h5'):
        encoder, decoder = load_encoder_decoder_pair(autoencoder, path)
        reconstructed = reconstruct_from_top_k(encoder, decoder, 
                                               active_neurons, sample)
        image_map[path] = reconstructed
    plot_reconstructed_from_top_k(image_map,
                                  f'images/neurons_active_{active_neurons}.png',
                                  (28, 28),
                                  active_neurons,
                                  show=True)
