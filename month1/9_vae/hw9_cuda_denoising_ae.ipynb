# %% [markdown]
# # <center>ДЗ по лекции 9: Автокодировщики

# %% [markdown]
# ### 1. Обучить многослойный автокодировщик:
# а. отрисовать классы в латентном представлении автокодировщика с двумерным латентным слоем,
# б. сделать tSNE над 32-мерным латентным слоем.
#
# ### 2. Обучить автокодировщик с шумом:
# а. Добавить ко входным данным нормальный шум,
# б. Сделать отражение части изображения,
# в. Визуализировать веса первого внутреннего слоя (кодирующего, get_weights, plot_mnist).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir('drive/My Drive/Colab Notebooks/neural_OTUS')

# %% [markdown]
# ## <center>Задание 1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

from utils import mnist, plot_graphs, plot_mnist, mnist_transform
import numpy as np

# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
mnist_transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.5,), (0.5,)),
           ])

train_loader, test_loader = mnist(batch_size=200, valid=0, transform=mnist_transform)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Создаем необходимые классы

# %%
class Encoder(nn.Module):
    def __init__(self, latent_size=10):
        super(Encoder, self).__init__()
        self.fc1 = nn.Linear(28*28, latent_size)
    
    def forward(self, x):
        x = torch.sigmoid(self.fc1(x))
        return x
    
class Decoder(nn.Module):
    def __init__(self, latent_size=10):
        super(Decoder, self).__init__()
        self.fc1 = nn.Linear(latent_size, 28*28)
    
    def forward(self, x):
        x = torch.tanh(self.fc1(x))
        return x

# %%
class Net(nn.Module):
    def __init__(self, latent_size=10, loss_fn=F.mse_loss, lr=1e-4, l2=0.):
        super(Net, self).__init__()
        self.latent_size = latent_size
        self.E = Encoder(latent_size).to(device)
        self.D = Decoder(latent_size).to(device)
        self.loss_fn = loss_fn
        self._loss = None
        self.optim = optim.Adam(self.parameters(), lr=lr, weight_decay=l2)
        
    def forward(self, x):
        x = x.view(-1, 28*28)
        h = self.E(x)
        out = self.D(h)
        return out
    
    def decode(self, h):
        with torch.no_grad():
            return self.D(h)
    
    def loss(self, x, target, **kwargs):
        target = target.view(-1, 28*28)
        self._loss = self.loss_fn(x, target, **kwargs)
        return self._loss

# %%
def train(epoch, models, loader, log=None, noise=False, mode='crop', elementwise=False, verbose_num=1):
    train_size = len(loader.sampler)
    for batch_idx, (data, _) in enumerate(loader):
        data = data.to(device)
        if noise:
            noised = add_noise(data, mode, elementwise)
        else:
            noised = data
        
        for model in models.values():
            model = model.to(device)
            model.optim.zero_grad()
            output = model(noised)
            loss = model.loss(output, data)
            loss.backward()
            model.optim.step()
            
    if log is not None:
        for k in models:
            log[k].append(models[k]._loss)   
            
    if epoch == 1 or epoch % verbose_num == 0:
        line = 'Epoch: {} [{}]\n'.format(epoch, train_size)
        losses = '\t' + 'Train set: ' + \
                 ' '.join(['{}: loss: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
        report = line + losses
        print(report)

# %%
def test(epoch, models, loader, log=None, noise=False, mode='crop', elementwise=False, verbose_num=1):
    test_size = len(loader.sampler)

    test_loss = {mod_label: 0. for mod_label in models}
    with torch.no_grad():
        for data, _ in loader:
            data = data.to(device)
            if noise:
                noised = add_noise(data, mode, elementwise)
            else:
                noised = data
            
            output = {mod_label: model(noised) for mod_label, model in models.items()}
            for mod_label, model in models.items():
                test_loss[mod_label] += model.loss(output[mod_label], noised, reduction='sum').item() # sum up batch loss
    
    for k in models:
        test_loss[k] /= (test_size * 784)
        if log is not None:
            log[k].append(test_loss[k])
    
    if epoch == 1 or epoch % verbose_num == 0:
        avg_lambda = lambda l: 'loss: {:.4f}'.format(l)
        line = lambda i, l: '{}: '.format(i) + avg_lambda(l)
        
        losses = ' '.join([line(k, test_loss[k]) for k in models])
        report = '\t' + 'Test set: ' + losses   
        print(report)

# %% [markdown]
# #### Тренируем автокодировщики с 2- и 32-мерным латентным слоем, включая, естественно, энкодер

# %%
models = {'2': Net(2), '32': Net(32)}
train_log = {k: [] for k in models}
test_log = {k: [] for k in models}

# %%
# %%time
for epoch in np.arange(100) + 1:
    for model in models.values():
        model.train()
    train(epoch, models, train_loader, train_log)
    for model in models.values():
        model.eval()
    test(epoch, models, test_loader, test_log)
# Out:
# Epoch: 1 [60000]
# 	Train set: 2: loss: 1.008713 32: loss: 0.392441
# 	Test set: 2: loss: 1.0078 32: loss: 0.4017
# Epoch: 2 [60000]
# 	Train set: 2: loss: 0.969470 32: loss: 0.287927
# 	Test set: 2: loss: 0.9691 32: loss: 0.2899
# Epoch: 3 [60000]
# 	Train set: 2: loss: 0.905785 32: loss: 0.265040
# 	Test set: 2: loss: 0.9080 32: loss: 0.2658
# Epoch: 4 [60000]
# 	Train set: 2: loss: 0.836600 32: loss: 0.255986
# 	Test set: 2: loss: 0.8368 32: loss: 0.2513
# Epoch: 5 [60000]
# 	Train set: 2: loss: 0.770415 32: loss: 0.240891
# 	Test set: 2: loss: 0.7701 32: loss: 0.2385
# Epoch: 6 [60000]
# 	Train set: 2: loss: 0.235039 32: loss: 0.056521
# 	Test set: 2: loss: 0.2264 32: loss: 0.0540
# Epoch: 94 [60000]
# 	Train set: 2: loss: 0.225670 32: loss: 0.055729
# 	Test set: 2: loss: 0.2263 32: loss: 0.0539
# Epoch: 95 [60000]
# 	Train set: 2: loss: 0.220710 32: loss: 0.051733
# 	Test set: 2: loss: 0.2261 32: loss: 0.0537
# Epoch: 96 [60000]
# 	Train set: 2: loss: 0.229809 32: loss: 0.056733
# 	Test set: 2: loss: 0.2260 32: loss: 0.0535
# Epoch: 97 [60000]
# 	Train set: 2: loss: 0.231371 32: loss: 0.055020
# 	Test set: 2: loss: 0.2258 32: loss: 0.0533
# Epoch: 98 [60000]
# 	Train set: 2: loss: 0.224244 32: loss: 0.054354
# 	Test set: 2: loss: 0.2257 32: loss: 0.0532
# Epoch: 99 [60000]
# 	Train set: 2: loss: 0.233306 32: loss: 0.053734
# 	Test set: 2: loss: 0.2256 32: loss: 0.0531
# Epoch: 100 [60000]
# 	Train set: 2: loss: 0.221208 32: loss: 0.050416
# 	Test set: 2: loss: 0.2255 32: loss: 0.0529
# CPU times: user 24min 59s, sys: 5.97 s, total: 25min 5s
# Wall time: 25min 6s

# %% [markdown]
# #### посмотрим на кривые обучения

# %%
for model in models:
    plt.plot(train_log[model], label="train")
    plt.plot(test_log[model], label="test")
    plt.title(f"loss, model: {model}")
    plt.xlabel("Epochs")
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# **Коммент:** модели, скорее всего, недообучены, но для наших целей уже достаточно

# %%
encoders ={model: models[model].E for model in models}

# %% [markdown]
# #### подготовим данные для визуализации

# %%
mnist_dataset = datasets.MNIST('./MNIST_data', train=True, download=True, transform=mnist_transform)

# %%
# %%time
mnist_data = list(torch.utils.data.DataLoader(mnist_dataset, batch_size=len(mnist_dataset)))[0]
mnist_data[0].shape, mnist_data[1].shape
# Out:
# CPU times: user 12.3 s, sys: 297 ms, total: 12.6 s
# Wall time: 12.6 s

# %%
def get_latent_out_labels(encoder, mnist_data, num_samples=200):
    data, targets = mnist_data
    x = data[:num_samples].to(device)
    labels = targets[:num_samples]
    with torch.no_grad():
        x = x.view(-1, 28*28)
        latent_outs = encoder(x)
    return latent_outs, labels

# %% [markdown]
# #### визуализируем 2-у мерные латентные представления

# %%
latent_outs, labels = get_latent_out_labels(encoders["2"], mnist_data, num_samples=10000)
latent_outs.shape, labels.shape
# Out:
# (torch.Size([10000, 2]), torch.Size([10000]))

# %%
plt.figure(figsize=(8, 8))
for label in np.unique(labels):
    mask = (labels == label)
    plt.scatter(latent_outs[mask].cpu()[:, 0], latent_outs[mask].cpu()[:, 1], s=15, label=label, alpha=0.5)
    plt.title("Kлассы в латентном представлении, \n2-у мерный вариант")
    plt.legend()

# %% [markdown]
# #### визуализируем 32-у мерные латентные представления через TSNE преобразование

# %%
from sklearn.manifold import TSNE

# %%
latent_outs32, labels32 = get_latent_out_labels(encoders["32"], mnist_data, num_samples=10000)
latent_outs32.shape, labels32.shape
# Out:
# (torch.Size([10000, 32]), torch.Size([10000]))

# %%
# %%time
latent_outs32_embedded = TSNE(n_components=2).fit_transform(latent_outs32.to("cpu"))
# Out:
# CPU times: user 1min 50s, sys: 224 ms, total: 1min 51s
# Wall time: 1min 51s

# %%
plt.figure(figsize=(8, 8))
for label in np.unique(labels32):
    mask = (labels32 == label)
    plt.scatter(latent_outs32_embedded[mask][:, 0], 
                latent_outs32_embedded[mask][:, 1], s=15, label=label, alpha=0.5)
    plt.title("Kлассы в латентном представлении, \n32-у мерный вариант через TSNE")
    plt.legend()

# %% [markdown]
# #### Коммент:
# 32-у мерный вариант латентного представления выглядит явно **поинтереснее**. Кроме того и лосс на кривых обучения заметно меньше, чем для 2-у мерного варианта

# %% [markdown]
# ## <center>Задание 2

# %% [markdown]
# #### делаем шум

# %%
def add_noise(x, mode='crop', elementwise=False, rand_noise=True):
    def local_mirror(area):
        dim = np.random.choice([1, 2])
        return torch.flip(area, [dim])
    
    if rand_noise:
        if np.random.randint(2):
            return x
    
    x = x.clone()
    if elementwise:
        if mode == 'crop':
            for i in range(x.shape[0]):
                img_part = np.random.randint(5)
                zero_one = np.random.randint(2)*2 - 1  # -1 or 1
                if img_part == 0:
                    x[i, :, :14, :14] = zero_one  # вторая размерность - похоже, цвет
                elif img_part == 1:
                    x[i, :, :14, 14:] = zero_one
                elif img_part == 2:
                    x[i, :, 14:, :14] = zero_one
                elif img_part == 3:
                    x[i, :, 14:, 14:] = zero_one
                elif img_part == 4:
                    x[i, :, 7:21, 7:21] = zero_one
        elif mode == 'mirror':
            for i in range(x.shape[0]):
                img_part = np.random.randint(5)
                if img_part == 0:
                    x[i, :, :14, :14] = local_mirror(x[i, :, :14, :14])
                elif img_part == 1:
                    x[i, :, :14, 14:] = local_mirror(x[i, :, :14, 14:])
                elif img_part == 2:
                    x[i, :, 14:, :14] = local_mirror(x[i, :, 14:, :14])
                elif img_part == 3:
                    x[i, :, 14:, 14:] = local_mirror(x[i, :, 14:, 14:])
                elif img_part == 4:
                    x[i, :, 7:21, 7:21] = local_mirror(x[i, :, 7:21, 7:21])
                    
        elif mode == 'gaussian':
            noise = torch.normal(0.5, 0.5, x.shape).to(x.device)
            x += noise
            
        elif mode == 'nonoise':
            pass

    else:
        if mode == 'crop':
            img_part = np.random.randint(5)
            zero_one = np.random.randint(2)*2 - 1
            if img_part == 0:
                x[:, :, :14, :14] = zero_one
            elif img_part == 1:
                x[:, :, :14, 14:] = zero_one
            elif img_part == 2:
                x[:, :, 14:, :14] = zero_one
            elif img_part == 3:
                x[:, :, 14:, 14:] = zero_one
            elif img_part == 4:
                x[:, :, 7:21, 7:21] = zero_one
    
    return x

# %% [markdown]
# #### тестируем шум

# %%
data, _ = next(iter(test_loader))
print("original")
plot_mnist(data.data.numpy()[:50], (5, 10))
data = data.to(device)
for mode in ["nonoise", "crop", "mirror", "gaussian"]:
    noized = add_noise(data, mode=mode, elementwise=True, rand_noise=False)
    print(mode)
    plot_mnist(noized[:50].cpu(), (5, 10))
# Out:
# original
# nonoise
# crop
# mirror
# gaussian

# %% [markdown]
# #### обучение с шумом

# %%
# %%time

noise_models = {}
logs = {}
noise_modes = ["nonoise", "crop", "mirror", "gaussian"]
epochs = 100

for noise_mode in noise_modes:
    noise_models[noise_mode] = {'64': Net(64)}
    logs[noise_mode] = {
        "train": {mod_label: [] for mod_label in noise_models[noise_mode]}, 
        "test": {mod_label: [] for mod_label in noise_models[noise_mode]}
    }
    print("noise_mode:", noise_mode)
    for epoch in np.arange(epochs) + 1:
        for model in noise_models[noise_mode].values():
            model.train()
        train(epoch, noise_models[noise_mode], train_loader, logs[noise_mode]["train"], 
              noise=True, mode=noise_mode, elementwise=True, verbose_num=10)
        for model in noise_models[noise_mode].values():
            model.eval()
        test(epoch, noise_models[noise_mode], test_loader, logs[noise_mode]["test"], 
             noise=True, mode=noise_mode, elementwise=True, verbose_num=10)
# Out:
# noise_mode: nonoise
# Epoch: 1 [60000]
# 	Train set: 64: loss: 0.293220
# 	Test set: 64: loss: 0.2913
# Epoch: 10 [60000]
# 	Train set: 64: loss: 0.130594
# 	Test set: 64: loss: 0.1251
# Epoch: 20 [60000]
# 	Train set: 64: loss: 0.073590
# 	Test set: 64: loss: 0.0740
# Epoch: 30 [60000]
# 	Train set: 64: loss: 0.057844
# 	Test set: 64: loss: 0.0528
# Epoch: 40 [60000]
# 	Train set: 64: loss: 0.042655
# 	Test set: 64: loss: 0.0419
# Epoch: 50 [60000]
# 	Train set: 64: loss: 0.036104
# 	Test set: 64: loss: 0.0355
# Epoch: 60 [60000]
# 	Train set: 64: loss: 0.032452
# 	Test set: 64: loss: 0.0313
# Epoch: 70 [60000]
# 	Train set: 64: loss: 0.028085
# 	Test set: 64: loss: 0.0284
# Epoch: 80 [60000]
# 	Train set: 64: loss: 0.026401
# 	Test set: 64: loss: 0.0264
# Epoch: 90 [60000]
# 	Train set: 64: loss: 0.023598
# 	Test set: 64: loss: 0.0248
# Epoch: 100 [60000]
# 	Train set: 64: loss: 0.023977
# 	Test set: 64: loss: 0.0236
# noise_mode: crop
# Epoch: 1 [60000]
# 	Train set: 64: loss: 0.307063
# 	Test set: 64: loss: 0.3896
# Epoch: 10 [60000]
# 	Train set: 64: loss: 0.172094
# 	Test set: 64: loss: 0.3046
# Epoch: 20 [60000]
# 	Train set: 64: loss: 0.094113
# 	Test set: 64: loss: 0.2612
# Epoch: 30 [60000]
# 	Train set: 64: loss: 0.111034
# 	Test set: 64: loss: 0.2733
# Epoch: 40 [60000]
# 	Train set: 64: loss: 0.096693
# 	Test set: 64: loss: 0.2240
# Epoch: 50 [60000]
# 	Train set: 64: loss: 0.095567
# 	Test set: 64: loss: 0.2409
# Epoch: 60 [60000]
# 	Train set: 64: loss: 0.092829
# 	Test set: 64: loss: 0.2040
# Epoch: 70 [60000]
# 	Train set: 64: loss: 0.046205
# 	Test set: 64: loss: 0.2651
# Epoch: 80 [60000]
# 	Train set: 64: loss: 0.086749
# 	Test set: 64: loss: 0.2777
# Epoch: 90 [60000]
# 	Train set: 64: loss: 0.081637
# 	Test set: 64: loss: 0.1969
# Epoch: 100 [60000]
# 	Train set: 64: loss: 0.082614
# 	Test set: 64: loss: 0.1786
# noise_mode: mirror
# Epoch: 1 [60000]
# 	Train set: 64: loss: 0.288708
# 	Test set: 64: loss: 0.3118
# Epoch: 10 [60000]
# 	Train set: 64: loss: 0.160471
# 	Test set: 64: loss: 0.1764
# Epoch: 20 [60000]
# 	Train set: 64: loss: 0.105044
# 	Test set: 64: loss: 0.1411
# Epoch: 30 [60000]
# 	Train set: 64: loss: 0.073044
# 	Test set: 64: loss: 0.1273
# Epoch: 40 [60000]
# 	Train set: 64: loss: 0.086772
# 	Test set: 64: loss: 0.1177
# Epoch: 50 [60000]
# 	Train set: 64: loss: 0.048267
# 	Test set: 64: loss: 0.0957
# Epoch: 60 [60000]
# 	Train set: 64: loss: 0.045161
# 	Test set: 64: loss: 0.0991
# Epoch: 70 [60000]
# 	Train set: 64: loss: 0.081366
# 	Test set: 64: loss: 0.0849
# Epoch: 80 [60000]
# 	Train set: 64: loss: 0.040189
# 	Test set: 64: loss: 0.1065
# Epoch: 90 [60000]
# 	Train set: 64: loss: 0.039064
# 	Test set: 64: loss: 0.1076
# Epoch: 100 [60000]
# 	Train set: 64: loss: 0.065468
# 	Test set: 64: loss: 0.1080
# noise_mode: gaussian
# Epoch: 1 [60000]
# 	Train set: 64: loss: 0.294906
# 	Test set: 64: loss: 0.4760
# Epoch: 10 [60000]
# 	Train set: 64: loss: 0.142551
# 	Test set: 64: loss: 0.4078
# Epoch: 20 [60000]
# 	Train set: 64: loss: 0.099621
# 	Test set: 64: loss: 0.3013
# Epoch: 30 [60000]
# 	Train set: 64: loss: 0.072144
# 	Test set: 64: loss: 0.2368
# Epoch: 40 [60000]
# 	Train set: 64: loss: 0.059527
# 	Test set: 64: loss: 0.2899
# Epoch: 50 [60000]
# 	Train set: 64: loss: 0.051680
# 	Test set: 64: loss: 0.2589
# Epoch: 60 [60000]
# 	Train set: 64: loss: 0.044430
# 	Test set: 64: loss: 0.2519
# Epoch: 70 [60000]
# 	Train set: 64: loss: 0.042056
# 	Test set: 64: loss: 0.2581
# Epoch: 80 [60000]
# 	Train set: 64: loss: 0.035439
# 	Test set: 64: loss: 0.2374
# Epoch: 90 [60000]
# 	Train set: 64: loss: 0.036109
# 	Test set: 64: loss: 0.2346
# Epoch: 100 [60000]
# 	Train set: 64: loss: 0.030732
# 	Test set: 64: loss: 0.2495
# CPU times: user 1h 7min 8s, sys: 34.5 s, total: 1h 7min 43s
# Wall time: 1h 7min 47s

# %% [markdown]
# ### Посмотрим на
#    - оригинальные данные
#    - зашумленные входы
#    - восстановленные выходы
#
# и сравним все это между собой

# %%
data, _ = next(iter(test_loader))
print("original data")
plot_mnist(data.data.numpy()[:50], (5, 10))
for noise_mode in noise_modes:
    models = noise_models[noise_mode]
    noized = add_noise(data, mode=noise_mode, elementwise=True, rand_noise=False)
    output = models['64'](noized[:50].to(device))
    to_plot = output.view(-1, 1, 28, 28).data.cpu().numpy()
    print(f"processed input: noise mode is {noise_mode}")
    plot_mnist(noized[:50], (5, 10))
    print(f"output after {noise_mode}")
    plot_mnist(to_plot, (5, 10))
# Out:
# original data
# processed input: noise mode is nonoise
# output after nonoise
# processed input: noise mode is crop
# output after crop
# processed input: noise mode is mirror
# output after mirror
# processed input: noise mode is gaussian
# output after gaussian

# %% [markdown]
# ### Визуализируем веса первого внутреннего слоя энкодера

# %%
for noise_mode in noise_modes:
    models = noise_models[noise_mode]
    to_plot = models["64"].E.fc1.weight.data.view(-1, 1, 28, 28).cpu().numpy()
    print(noise_mode)
    plot_mnist(to_plot, (8, 8))
# Out:
# nonoise
# crop
# mirror
# gaussian
