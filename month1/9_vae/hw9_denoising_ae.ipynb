# %% [markdown]
# # <center>ДЗ по лекции 9: Автокодировщики

# %% [markdown]
# ### 1. Обучить многослойный автокодировщик:
# а. отрисовать классы в латентном представлении автокодировщика с двумерным латентным слоем,
# б. сделать tSNE над 32-мерным латентным слоем.
#
# ### 2. Обучить автокодировщик с шумом:
# а. Добавить ко входным данным нормальный шум,
# б. Сделать отражение части изображения,
# в. Визуализировать веса первого внутреннего слоя (кодирующего, get_weights, plot_mnist).

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

from utils import mnist, plot_graphs, plot_mnist, mnist_transform
import numpy as np

# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
mnist_transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.5,), (0.5,)),
           ])

train_loader, test_loader = mnist(batch_size=200, valid=0, transform=mnist_transform)

# %% [markdown]
# ## Создаем необходимые классы

# %%
class Encoder(nn.Module):
    def __init__(self, latent_size=10):
        super(Encoder, self).__init__()
        self.fc1 = nn.Linear(28*28, latent_size)
    
    def forward(self, x):
        x = torch.sigmoid(self.fc1(x))
        return x
    
class Decoder(nn.Module):
    def __init__(self, latent_size=10):
        super(Decoder, self).__init__()
        self.fc1 = nn.Linear(latent_size, 28*28)
    
    def forward(self, x):
        x = torch.tanh(self.fc1(x))
        return x

# %%
class Net(nn.Module):
    def __init__(self, latent_size=10, loss_fn=F.mse_loss, lr=1e-4, l2=0.):
        super(Net, self).__init__()
        self.latent_size = latent_size
        self.E = Encoder(latent_size)
        self.D = Decoder(latent_size)
        self.loss_fn = loss_fn
        self._loss = None
        self.optim = optim.Adam(self.parameters(), lr=lr, weight_decay=l2)
        
    def forward(self, x):
        x = x.view(-1, 28*28)
        h = self.E(x)
        out = self.D(h)
        return out
    
    def decode(self, h):
        with torch.no_grad():
            return self.D(h)
    
    def loss(self, x, target, **kwargs):
        target = target.view(-1, 28*28)
        self._loss = self.loss_fn(x, target, **kwargs)
        return self._loss

# %%
def train(epoch, models, log=None, noise=False):
    train_size = len(train_loader.sampler)
    for batch_idx, (data, _) in enumerate(train_loader):
        if noise:
            data = add_noise(data)
        for model in models.values():
            model.optim.zero_grad()
            output = model(data)
            loss = model.loss(output, data)
            loss.backward()
            model.optim.step()
            
    if log is not None:
        for k in models:
            log[k].append(models[k]._loss)   
            
    line = 'Epoch: {} [{}]\n'.format(epoch, train_size)
    losses = '\t' + 'Train set: ' + \
             ' '.join(['{}: loss: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
    report = line + losses
    print(report)

# %%
def test(models, loader, log=None, noise=False):
    test_size = len(loader.sampler)

    test_loss = {k: 0. for k in models}
    with torch.no_grad():
        for data, _ in loader:
            if noise:
                data = add_noise(data)
            output = {k: m(data) for k, m in models.items()}
            for k, m in models.items():
                test_loss[k] += m.loss(output[k], data, reduction='sum').item() # sum up batch loss
    
    for k in models:
        test_loss[k] /= (test_size * 784)
        if log is not None:
            log[k].append(test_loss[k])
    
    avg_lambda = lambda l: 'loss: {:.4f}'.format(l)
    line = lambda i, l: '{}: '.format(i) + avg_lambda(l)
    
    losses = ' '.join([line(k, test_loss[k]) for k in models])
    report = '\t' + 'Test set: ' + losses        
    print(report)

# %% [markdown]
# #### Тренируем автокодировщики с 2- и 32-мерным латентным слоем, включая, естественно, энкодер

# %%
models = {'2': Net(2), '32': Net(32)}
train_log = {k: [] for k in models}
test_log = {k: [] for k in models}

# %%
# %%time
for epoch in np.arange(100) + 1:
    for model in models.values():
        model.train()
    train(epoch, models, train_log)
    for model in models.values():
        model.eval()
    test(models, test_loader, test_log)
# Out:
# Epoch: 1 [60000]
# 	Train set: 2: loss: 1.039214 32: loss: 0.412734
# 	Test set: 2: loss: 1.0391 32: loss: 0.4144
# Epoch: 2 [60000]
# 	Train set: 2: loss: 0.957129 32: loss: 0.294602
# 	Test set: 2: loss: 0.9583 32: loss: 0.2976
# Epoch: 3 [60000]
# 	Train set: 2: loss: 0.866590 32: loss: 0.270619
# 	Test set: 2: loss: 0.8685 32: loss: 0.2742
# Epoch: 4 [60000]
# 	Train set: 2: loss: 0.778228 32: loss: 0.259354
# 	Test set: 2: loss: 0.7807 32: loss: 0.2574
# Epoch: 5 [60000]
# 	Train set: 2: loss: 0.702683 32: loss: 0.240903
# 	Test set: 2: loss: 0.7023 32: loss: 0.2398
# Epoch: 6 [60000]
# 	Train set: 2: loss: 0.632054 32: loss: 0.221977
# 	Test set: 2: loss: 0.6359 32: loss: 0.2261
# Epoch: 7 [60000]
# 	Train set: 2: loss: 0.577730 32: loss: 0.214566
# 	Test set: 2: loss: 0.5793 32: loss: 0.2145
# Epoch: 8 [60000]
# 	Train set: 2: loss: 0.529509 32: loss: 0.204443
# 	Test set: 2: loss: 0.5307 32: loss: 0.2034
# Epoch: 9 [60000]
# 	Train set: 2: loss: 0.485540 32: loss: 0.190883
# 	Test set: 2: loss: 0.4891 32: loss: 0.1926
# Epoch: 10 [60000]
# 	Train set: 2: loss: 0.450831 32: loss: 0.178817
# 	Test set: 2: loss: 0.4536 32: loss: 0.1823
# Epoch: 11 [60000]
# 	Train set: 2: loss: 0.422837 32: loss: 0.174619
# 	Test set: 2: loss: 0.4235 32: loss: 0.1728
# Epoch: 12 [60000]
# 	Train set: 2: loss: 0.397449 32: loss: 0.164709
# 	Test set: 2: loss: 0.3981 32: loss: 0.1641
# Epoch: 13 [60000]
# 	Train set: 2: loss: 0.373496 32: loss: 0.157727
# 	Test set: 2: loss: 0.3768 32: loss: 0.1565
# Epoch: 14 [60000]
# 	Train set: 2: loss: 0.351802 32: loss: 0.149036
# 	Test set: 2: loss: 0.3591 32: loss: 0.1498
# Epoch: 15 [60000]
# 	Train set: 2: loss: 0.342420 32: loss: 0.143581
# 	Test set: 2: loss: 0.3444 32: loss: 0.1437
# Epoch: 16 [60000]
# 	Train set: 2: loss: 0.342657 32: loss: 0.145110
# 	Test set: 2: loss: 0.3322 32: loss: 0.1382
# Epoch: 17 [60000]
# 	Train set: 2: loss: 0.315357 32: loss: 0.133177
# 	Test set: 2: loss: 0.3220 32: loss: 0.1332
# Epoch: 18 [60000]
# 	Train set: 2: loss: 0.320477 32: loss: 0.135918
# 	Test set: 2: loss: 0.3136 32: loss: 0.1286
# Epoch: 19 [60000]
# 	Train set: 2: loss: 0.305491 32: loss: 0.126180
# 	Test set: 2: loss: 0.3067 32: loss: 0.1244
# Epoch: 20 [60000]
# 	Train set: 2: loss: 0.306822 32: loss: 0.130264
# 	Test set: 2: loss: 0.3009 32: loss: 0.1205
# Epoch: 21 [60000]
# 	Train set: 2: loss: 0.303614 32: loss: 0.119495
# 	Test set: 2: loss: 0.2960 32: loss: 0.1168
# Epoch: 22 [60000]
# 	Train set: 2: loss: 0.289172 32: loss: 0.112954
# 	Test set: 2: loss: 0.2919 32: loss: 0.1135
# Epoch: 23 [60000]
# 	Train set: 2: loss: 0.286245 32: loss: 0.109778
# 	Test set: 2: loss: 0.2885 32: loss: 0.1101
# Epoch: 24 [60000]
# 	Train set: 2: loss: 0.291986 32: loss: 0.110894
# 	Test set: 2: loss: 0.2855 32: loss: 0.1071
# Epoch: 25 [60000]
# 	Train set: 2: loss: 0.281418 32: loss: 0.104089
# 	Test set: 2: loss: 0.2829 32: loss: 0.1042
# Epoch: 26 [60000]
# 	Train set: 2: loss: 0.281847 32: loss: 0.105714
# 	Test set: 2: loss: 0.2807 32: loss: 0.1016
# Epoch: 27 [60000]
# 	Train set: 2: loss: 0.273731 32: loss: 0.098641
# 	Test set: 2: loss: 0.2787 32: loss: 0.0992
# Epoch: 28 [60000]
# 	Train set: 2: loss: 0.274045 32: loss: 0.098564
# 	Test set: 2: loss: 0.2770 32: loss: 0.0969
# Epoch: 29 [60000]
# 	Train set: 2: loss: 0.266058 32: loss: 0.091283
# 	Test set: 2: loss: 0.2754 32: loss: 0.0947
# Epoch: 30 [60000]
# 	Train set: 2: loss: 0.267657 32: loss: 0.091899
# 	Test set: 2: loss: 0.2740 32: loss: 0.0927
# Epoch: 31 [60000]
# 	Train set: 2: loss: 0.268516 32: loss: 0.092270
# 	Test set: 2: loss: 0.2727 32: loss: 0.0908
# Epoch: 32 [60000]
# 	Train set: 2: loss: 0.262798 32: loss: 0.087095
# 	Test set: 2: loss: 0.2714 32: loss: 0.0890
# Epoch: 33 [60000]
# 	Train set: 2: loss: 0.276011 32: loss: 0.090338
# 	Test set: 2: loss: 0.2702 32: loss: 0.0874
# Epoch: 34 [60000]
# 	Train set: 2: loss: 0.266880 32: loss: 0.087011
# 	Test set: 2: loss: 0.2691 32: loss: 0.0857
# Epoch: 35 [60000]
# 	Train set: 2: loss: 0.269062 32: loss: 0.084819
# 	Test set: 2: loss: 0.2679 32: loss: 0.0843
# Epoch: 36 [60000]
# 	Train set: 2: loss: 0.274638 32: loss: 0.088360
# 	Test set: 2: loss: 0.2668 32: loss: 0.0828
# Epoch: 37 [60000]
# 	Train set: 2: loss: 0.260070 32: loss: 0.079839
# 	Test set: 2: loss: 0.2656 32: loss: 0.0815
# Epoch: 38 [60000]
# 	Train set: 2: loss: 0.260910 32: loss: 0.082789
# 	Test set: 2: loss: 0.2645 32: loss: 0.0802
# Epoch: 39 [60000]
# 	Train set: 2: loss: 0.255210 32: loss: 0.077198
# 	Test set: 2: loss: 0.2633 32: loss: 0.0790
# Epoch: 40 [60000]
# 	Train set: 2: loss: 0.258143 32: loss: 0.079380
# 	Test set: 2: loss: 0.2621 32: loss: 0.0779
# Epoch: 41 [60000]
# 	Train set: 2: loss: 0.263429 32: loss: 0.080316
# 	Test set: 2: loss: 0.2610 32: loss: 0.0768
# Epoch: 42 [60000]
# 	Train set: 2: loss: 0.258174 32: loss: 0.079202
# 	Test set: 2: loss: 0.2598 32: loss: 0.0758
# Epoch: 43 [60000]
# 	Train set: 2: loss: 0.263926 32: loss: 0.075790
# 	Test set: 2: loss: 0.2587 32: loss: 0.0748
# Epoch: 44 [60000]
# 	Train set: 2: loss: 0.255151 32: loss: 0.075116
# 	Test set: 2: loss: 0.2577 32: loss: 0.0739
# Epoch: 45 [60000]
# 	Train set: 2: loss: 0.258836 32: loss: 0.074843
# 	Test set: 2: loss: 0.2566 32: loss: 0.0730
# Epoch: 46 [60000]
# 	Train set: 2: loss: 0.256229 32: loss: 0.074545
# 	Test set: 2: loss: 0.2556 32: loss: 0.0721
# Epoch: 47 [60000]
# 	Train set: 2: loss: 0.248298 32: loss: 0.074302
# 	Test set: 2: loss: 0.2546 32: loss: 0.0713
# Epoch: 48 [60000]
# 	Train set: 2: loss: 0.256456 32: loss: 0.071264
# 	Test set: 2: loss: 0.2537 32: loss: 0.0705
# Epoch: 49 [60000]
# 	Train set: 2: loss: 0.254659 32: loss: 0.072104
# 	Test set: 2: loss: 0.2528 32: loss: 0.0698
# Epoch: 50 [60000]
# 	Train set: 2: loss: 0.251218 32: loss: 0.069995
# 	Test set: 2: loss: 0.2519 32: loss: 0.0691
# Epoch: 51 [60000]
# 	Train set: 2: loss: 0.254964 32: loss: 0.074049
# 	Test set: 2: loss: 0.2510 32: loss: 0.0684
# Epoch: 52 [60000]
# 	Train set: 2: loss: 0.248219 32: loss: 0.066201
# 	Test set: 2: loss: 0.2502 32: loss: 0.0677
# Epoch: 53 [60000]
# 	Train set: 2: loss: 0.252762 32: loss: 0.068029
# 	Test set: 2: loss: 0.2493 32: loss: 0.0671
# Epoch: 54 [60000]
# 	Train set: 2: loss: 0.245014 32: loss: 0.066068
# 	Test set: 2: loss: 0.2485 32: loss: 0.0665
# Epoch: 55 [60000]
# 	Train set: 2: loss: 0.250447 32: loss: 0.066560
# 	Test set: 2: loss: 0.2477 32: loss: 0.0659
# Epoch: 56 [60000]
# 	Train set: 2: loss: 0.249957 32: loss: 0.066932
# 	Test set: 2: loss: 0.2469 32: loss: 0.0654
# Epoch: 57 [60000]
# 	Train set: 2: loss: 0.235279 32: loss: 0.063452
# 	Test set: 2: loss: 0.2462 32: loss: 0.0648
# Epoch: 58 [60000]
# 	Train set: 2: loss: 0.251760 32: loss: 0.069454
# 	Test set: 2: loss: 0.2454 32: loss: 0.0643
# Epoch: 59 [60000]
# 	Train set: 2: loss: 0.241712 32: loss: 0.064783
# 	Test set: 2: loss: 0.2447 32: loss: 0.0638
# Epoch: 60 [60000]
# 	Train set: 2: loss: 0.245201 32: loss: 0.066876
# 	Test set: 2: loss: 0.2439 32: loss: 0.0633
# Epoch: 61 [60000]
# 	Train set: 2: loss: 0.241922 32: loss: 0.065935
# 	Test set: 2: loss: 0.2432 32: loss: 0.0629
# Epoch: 62 [60000]
# 	Train set: 2: loss: 0.249474 32: loss: 0.065635
# 	Test set: 2: loss: 0.2425 32: loss: 0.0624
# Epoch: 63 [60000]
# 	Train set: 2: loss: 0.241520 32: loss: 0.062627
# 	Test set: 2: loss: 0.2418 32: loss: 0.0620
# Epoch: 64 [60000]
# 	Train set: 2: loss: 0.246658 32: loss: 0.066570
# 	Test set: 2: loss: 0.2411 32: loss: 0.0616
# Epoch: 65 [60000]
# 	Train set: 2: loss: 0.247680 32: loss: 0.064118
# 	Test set: 2: loss: 0.2404 32: loss: 0.0612
# Epoch: 66 [60000]
# 	Train set: 2: loss: 0.237972 32: loss: 0.061530
# 	Test set: 2: loss: 0.2398 32: loss: 0.0608
# Epoch: 67 [60000]
# 	Train set: 2: loss: 0.234855 32: loss: 0.060422
# 	Test set: 2: loss: 0.2392 32: loss: 0.0604
# Epoch: 68 [60000]
# 	Train set: 2: loss: 0.237925 32: loss: 0.062368
# 	Test set: 2: loss: 0.2385 32: loss: 0.0601
# Epoch: 69 [60000]
# 	Train set: 2: loss: 0.230449 32: loss: 0.059657
# 	Test set: 2: loss: 0.2380 32: loss: 0.0597
# Epoch: 70 [60000]
# 	Train set: 2: loss: 0.237600 32: loss: 0.059101
# 	Test set: 2: loss: 0.2374 32: loss: 0.0594
# Epoch: 71 [60000]
# 	Train set: 2: loss: 0.226670 32: loss: 0.057144
# 	Test set: 2: loss: 0.2368 32: loss: 0.0591
# Epoch: 72 [60000]
# 	Train set: 2: loss: 0.244598 32: loss: 0.060724
# 	Test set: 2: loss: 0.2363 32: loss: 0.0588
# Epoch: 73 [60000]
# 	Train set: 2: loss: 0.234523 32: loss: 0.062132
# 	Test set: 2: loss: 0.2358 32: loss: 0.0584
# Epoch: 74 [60000]
# 	Train set: 2: loss: 0.226253 32: loss: 0.055484
# 	Test set: 2: loss: 0.2353 32: loss: 0.0581
# Epoch: 75 [60000]
# 	Train set: 2: loss: 0.232162 32: loss: 0.058073
# 	Test set: 2: loss: 0.2349 32: loss: 0.0578
# Epoch: 76 [60000]
# 	Train set: 2: loss: 0.240152 32: loss: 0.060474
# 	Test set: 2: loss: 0.2344 32: loss: 0.0575
# Epoch: 77 [60000]
# 	Train set: 2: loss: 0.238334 32: loss: 0.059478
# 	Test set: 2: loss: 0.2340 32: loss: 0.0573
# Epoch: 78 [60000]
# 	Train set: 2: loss: 0.236844 32: loss: 0.061337
# 	Test set: 2: loss: 0.2336 32: loss: 0.0570
# Epoch: 79 [60000]
# 	Train set: 2: loss: 0.230796 32: loss: 0.055954
# 	Test set: 2: loss: 0.2332 32: loss: 0.0567
# Epoch: 80 [60000]
# 	Train set: 2: loss: 0.235199 32: loss: 0.059103
# 	Test set: 2: loss: 0.2328 32: loss: 0.0565
# Epoch: 81 [60000]
# 	Train set: 2: loss: 0.240366 32: loss: 0.059344
# 	Test set: 2: loss: 0.2324 32: loss: 0.0562
# Epoch: 82 [60000]
# 	Train set: 2: loss: 0.232439 32: loss: 0.059160
# 	Test set: 2: loss: 0.2321 32: loss: 0.0560
# Epoch: 83 [60000]
# 	Train set: 2: loss: 0.235803 32: loss: 0.057846
# 	Test set: 2: loss: 0.2317 32: loss: 0.0558
# Epoch: 84 [60000]
# 	Train set: 2: loss: 0.231963 32: loss: 0.056924
# 	Test set: 2: loss: 0.2314 32: loss: 0.0555
# Epoch: 85 [60000]
# 	Train set: 2: loss: 0.229477 32: loss: 0.055604
# 	Test set: 2: loss: 0.2311 32: loss: 0.0553
# Epoch: 86 [60000]
# 	Train set: 2: loss: 0.238081 32: loss: 0.055917
# 	Test set: 2: loss: 0.2308 32: loss: 0.0551
# Epoch: 87 [60000]
# 	Train set: 2: loss: 0.222356 32: loss: 0.054539
# 	Test set: 2: loss: 0.2305 32: loss: 0.0549
# Epoch: 88 [60000]
# 	Train set: 2: loss: 0.225006 32: loss: 0.054119
# 	Test set: 2: loss: 0.2303 32: loss: 0.0547
# Epoch: 89 [60000]
# 	Train set: 2: loss: 0.218102 32: loss: 0.053194
# 	Test set: 2: loss: 0.2300 32: loss: 0.0545
# Epoch: 90 [60000]
# 	Train set: 2: loss: 0.236593 32: loss: 0.060275
# 	Test set: 2: loss: 0.2298 32: loss: 0.0543
# Epoch: 91 [60000]
# 	Train set: 2: loss: 0.229462 32: loss: 0.055200
# 	Test set: 2: loss: 0.2295 32: loss: 0.0541
# Epoch: 92 [60000]
# 	Train set: 2: loss: 0.228202 32: loss: 0.054618
# 	Test set: 2: loss: 0.2293 32: loss: 0.0539
# Epoch: 93 [60000]
# 	Train set: 2: loss: 0.214570 32: loss: 0.052810
# 	Test set: 2: loss: 0.2291 32: loss: 0.0538
# Epoch: 94 [60000]
# 	Train set: 2: loss: 0.230881 32: loss: 0.055340
# 	Test set: 2: loss: 0.2288 32: loss: 0.0536
# Epoch: 95 [60000]
# 	Train set: 2: loss: 0.235263 32: loss: 0.054737
# 	Test set: 2: loss: 0.2286 32: loss: 0.0534
# Epoch: 96 [60000]
# 	Train set: 2: loss: 0.230812 32: loss: 0.056551
# 	Test set: 2: loss: 0.2284 32: loss: 0.0532
# Epoch: 97 [60000]
# 	Train set: 2: loss: 0.225136 32: loss: 0.053618
# 	Test set: 2: loss: 0.2282 32: loss: 0.0531
# Epoch: 98 [60000]
# 	Train set: 2: loss: 0.230311 32: loss: 0.055081
# 	Test set: 2: loss: 0.2281 32: loss: 0.0529
# Epoch: 99 [60000]
# 	Train set: 2: loss: 0.226359 32: loss: 0.052270
# 	Test set: 2: loss: 0.2279 32: loss: 0.0527
# Epoch: 100 [60000]
# 	Train set: 2: loss: 0.228543 32: loss: 0.054010
# 	Test set: 2: loss: 0.2277 32: loss: 0.0526
# Wall time: 59min 5s

# %% [markdown]
# #### посмотрим на кривые обучения

# %%
for model in models:
    plt.plot(train_log[model], label="train")
    plt.plot(test_log[model], label="test")
    plt.title(f"loss, model: {model}")
    plt.xlabel("Epochs")
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# **Коммент:** модели, скорее всего, недообучены, но для наших целей достаточно

# %%
encoders ={model: models[model].E for model in models}

# %% [markdown]
# #### подготовим данные для визуализации

# %%
mnist_dataset = datasets.MNIST('./MNIST_data', train=True, download=True, transform=mnist_transform)

# %%
# %%time
mnist_data = list(torch.utils.data.DataLoader(mnist_dataset, batch_size=len(mnist_dataset)))[0]
mnist_data[0].shape, mnist_data[1].shape
# Out:
# Wall time: 12.5 s
# (torch.Size([60000, 1, 28, 28]), torch.Size([60000]))

# %%
def get_latent_out_labels(encoder, mnist_data, num_samples=200):
    data, targets = mnist_data
    x = data[:num_samples]
    labels = targets[:num_samples]
    with torch.no_grad():
        x = x.view(-1, 28*28)
        latent_outs = encoder(x)
    return latent_outs, labels

# %% [markdown]
# #### визуализируем 2-у мерные латентные представления

# %%
latent_outs, labels = get_latent_out_labels(encoders["2"], mnist_data, num_samples=10000)
latent_outs.shape, labels.shape
# Out:
# (torch.Size([10000, 2]), torch.Size([10000]))

# %%
plt.figure(figsize=(8, 8))
for label in np.unique(labels):
    mask = (labels == label)
    plt.scatter(latent_outs[mask][:, 0], latent_outs[mask][:, 1], s=15, label=label, alpha=0.5)
    plt.title("Kлассы в латентном представлении, \n2-у мерный вариант")
    plt.legend()

# %% [markdown]
# #### визуализируем 32-у мерные латентные представления через TSNE преобразование

# %%
from sklearn.manifold import TSNE

# %%
latent_outs32, labels32 = get_latent_out_labels(encoders["32"], mnist_data, num_samples=10000)
latent_outs32.shape, labels32.shape
# Out:
# (torch.Size([10000, 32]), torch.Size([10000]))

# %%
# %%time
latent_outs32_embedded = TSNE(n_components=2).fit_transform(latent_outs32)
# Out:
# Wall time: 1min 50s

# %%
plt.figure(figsize=(8, 8))
for label in np.unique(labels32):
    mask = (labels32 == label)
    plt.scatter(latent_outs32_embedded[mask][:, 0], 
                latent_outs32_embedded[mask][:, 1], s=15, label=label, alpha=0.5)
    plt.title("Kлассы в латентном представлении, \n32-у мерный вариант через TSNE")
    plt.legend()

# %% [markdown]
# #### Коммент:
# 32-у мерный вариант латентного представления выглядит явно поинтереснее. Кроме того и лосс на кривых обучения заметно меньше, чем для 2-у мерного варианта

# %%
models = {'16': Net(16), '32': Net(32), '64': Net(64)}
train_log = {k: [] for k in models}
test_log = {k: [] for k in models}

# %%
def add_noise(x, mode='crop', elementwise=False):
    if np.random.randint(2):
        return x
    x = x.clone()
    if elementwise:
        if mode == 'crop':
            for i in range(x.shape[0]):
                img_part = np.random.randint(5)
                zero_one = np.random.randint(2)*2 - 1  # -1 or 1
                if img_part == 0:
                    x[i, :, :14, :14] = zero_one  # вторая размерность - похоже, цвет (?)
                elif img_part == 1:
                    x[i, :, :14, 14:] = zero_one
                elif img_part == 2:
                    x[i, :, 14:, :14] = zero_one
                elif img_part == 3:
                    x[i, :, 14:, 14:] = zero_one
                elif img_part == 4:
                    x[i, :, 7:21, 7:21] = zero_one
        elif mode == 'mirror':
            pass
        elif mode == 'gaussian':
            pass    
    else:
        if mode == 'crop':
            img_part = np.random.randint(5)
            zero_one = np.random.randint(2)*2 - 1
            if img_part == 0:
                x[:, :, :14, :14] = zero_one
            elif img_part == 1:
                x[:, :, :14, 14:] = zero_one
            elif img_part == 2:
                x[:, :, 14:, :14] = zero_one
            elif img_part == 3:
                x[:, :, 14:, 14:] = zero_one
            elif img_part == 4:
                x[:, :, 7:21, 7:21] = zero_one
    return x

# %% [markdown]
# #### тестируем обучение

# %%
# for epoch in range(1, 21):
for epoch in range(1, 3):
    for model in models.values():
        model.train()
    train(epoch, models, train_log)
    for model in models.values():
        model.eval()
    test(models, test_loader, test_log)
# Out:
# Train Epoch: 1 [00000/60000] 16: 0.270630 32: 0.251899 64: 0.216521
# Train Epoch: 1 [30000/60000] 16: 0.264952 32: 0.242280 64: 0.203433
# Train Epoch: 1 [60000/60000] 16: 0.261351 32: 0.230407 64: 0.185376
# Test set:
# 16: loss: 0.2647
# 32: loss: 0.2363
# 64: loss: 0.1939
#
# Train Epoch: 2 [00000/60000] 16: 0.273534 32: 0.245468 64: 0.200539
# Train Epoch: 2 [30000/60000] 16: 0.255383 32: 0.226441 64: 0.184402
# Train Epoch: 2 [60000/60000] 16: 0.261780 32: 0.231490 64: 0.190043
# Test set:
# 16: loss: 0.2613
# 32: loss: 0.2295
# 64: loss: 0.1866

# %%
for epoch in range(1, 21):
    for model in models.values():
        model.train()
    train(epoch, models, train_log)
    for model in models.values():
        model.eval()
    test(models, test_loader, test_log)
# Out:
# Train Epoch: 1 [00000/60000 (0%)] 16: 1.044241 32: 1.016514 64: 0.981115
# Train Epoch: 1 [30000/60000 (50%)] 16: 0.871733 32: 0.662759 64: 0.415461
# Train Epoch: 1 [60000/60000 (100%)] 16: 0.683663 32: 0.426546 64: 0.306121
# Test set:
# 16: loss: 0.6697
# 32: loss: 0.4096
# 64: loss: 0.2953
#
# Train Epoch: 2 [00000/60000 (0%)] 16: 0.671488 32: 0.415529 64: 0.304643
# Train Epoch: 2 [30000/60000 (50%)] 16: 0.494269 32: 0.317786 64: 0.274582
# Train Epoch: 2 [60000/60000 (100%)] 16: 0.392515 32: 0.293021 64: 0.269764
# Test set:
# 16: loss: 0.3955
# 32: loss: 0.2944
# 64: loss: 0.2693
#
# Train Epoch: 3 [00000/60000 (0%)] 16: 0.388266 32: 0.287929 64: 0.264279
# Train Epoch: 3 [30000/60000 (50%)] 16: 0.342828 32: 0.285113 64: 0.268864
# Train Epoch: 3 [60000/60000 (100%)] 16: 0.311963 32: 0.273006 64: 0.247174
# Test set:
# 16: loss: 0.3167
# 32: loss: 0.2781
# 64: loss: 0.2550
#
# Train Epoch: 4 [00000/60000 (0%)] 16: 0.313526 32: 0.275377 64: 0.251002
# Train Epoch: 4 [30000/60000 (50%)] 16: 0.299895 32: 0.274049 64: 0.257251
# Train Epoch: 4 [60000/60000 (100%)] 16: 0.290410 32: 0.268643 64: 0.237039
# Test set:
# 16: loss: 0.2935
# 32: loss: 0.2708
# 64: loss: 0.2401
#
# Train Epoch: 5 [00000/60000 (0%)] 16: 0.286563 32: 0.264129 64: 0.232904
# Train Epoch: 5 [30000/60000 (50%)] 16: 0.289669 32: 0.271227 64: 0.241398
# Train Epoch: 5 [60000/60000 (100%)] 16: 0.276975 32: 0.255976 64: 0.216658
# Test set:
# 16: loss: 0.2838
# 32: loss: 0.2636
# 64: loss: 0.2262
#
# Train Epoch: 6 [00000/60000 (0%)] 16: 0.276986 32: 0.256055 64: 0.216688
# Train Epoch: 6 [30000/60000 (50%)] 16: 0.283236 32: 0.262233 64: 0.218425
# Train Epoch: 6 [60000/60000 (100%)] 16: 0.272328 32: 0.252740 64: 0.214442
# Test set:
# 16: loss: 0.2775
# 32: loss: 0.2556
# 64: loss: 0.2129
#
# Train Epoch: 7 [00000/60000 (0%)] 16: 0.271798 32: 0.249922 64: 0.204837
# Train Epoch: 7 [30000/60000 (50%)] 16: 0.269268 32: 0.248075 64: 0.206370
# Train Epoch: 7 [60000/60000 (100%)] 16: 0.269660 32: 0.248279 64: 0.205387
# Test set:
# 16: loss: 0.2723
# 32: loss: 0.2492
# 64: loss: 0.2039
#
# Train Epoch: 8 [00000/60000 (0%)] 16: 0.272728 32: 0.251281 64: 0.208020
# Train Epoch: 8 [30000/60000 (50%)] 16: 0.266227 32: 0.241293 64: 0.194467
# Train Epoch: 8 [60000/60000 (100%)] 16: 0.265967 32: 0.240991 64: 0.192238
# Test set:
# 16: loss: 0.2673
# 32: loss: 0.2411
# 64: loss: 0.1910
#
# Train Epoch: 9 [00000/60000 (0%)] 16: 0.266287 32: 0.246485 64: 0.218922
# Train Epoch: 9 [30000/60000 (50%)] 16: 0.269808 32: 0.238981 64: 0.181326
# Train Epoch: 9 [60000/60000 (100%)] 16: 0.267446 32: 0.237798 64: 0.189123
# Test set:
# 16: loss: 0.2641
# 32: loss: 0.2351
# 64: loss: 0.1865
#
# Train Epoch: 10 [00000/60000 (0%)] 16: 0.264709 32: 0.237838 64: 0.189455
# Train Epoch: 10 [30000/60000 (50%)] 16: 0.259324 32: 0.230229 64: 0.181699
# Train Epoch: 10 [60000/60000 (100%)] 16: 0.265474 32: 0.232630 64: 0.184509
# Test set:
# 16: loss: 0.2599
# 32: loss: 0.2253
# 64: loss: 0.1738
#
# Train Epoch: 11 [00000/60000 (0%)] 16: 0.259708 32: 0.237753 64: 0.207542
# Train Epoch: 11 [30000/60000 (50%)] 16: 0.263712 32: 0.223879 64: 0.166406
# Train Epoch: 11 [60000/60000 (100%)] 16: 0.258771 32: 0.215544 64: 0.156300
# Test set:
# 16: loss: 0.2567
# 32: loss: 0.2171
# 64: loss: 0.1664
#
# Train Epoch: 12 [00000/60000 (0%)] 16: 0.249786 32: 0.211524 64: 0.162974
# Train Epoch: 12 [30000/60000 (50%)] 16: 0.257874 32: 0.212503 64: 0.156035
# Train Epoch: 12 [60000/60000 (100%)] 16: 0.256459 32: 0.226364 64: 0.199499
# Test set:
# 16: loss: 0.2540
# 32: loss: 0.2109
# 64: loss: 0.1629
#
# Train Epoch: 13 [00000/60000 (0%)] 16: 0.251156 32: 0.209982 64: 0.164149
# Train Epoch: 13 [30000/60000 (50%)] 16: 0.245763 32: 0.203416 64: 0.158191
# Train Epoch: 13 [60000/60000 (100%)] 16: 0.251225 32: 0.205088 64: 0.162345
# Test set:
# 16: loss: 0.2489
# 32: loss: 0.1996
# 64: loss: 0.1492
#
# Train Epoch: 14 [00000/60000 (0%)] 16: 0.255337 32: 0.202791 64: 0.146950
# Train Epoch: 14 [30000/60000 (50%)] 16: 0.245533 32: 0.202938 64: 0.157948
# Train Epoch: 14 [60000/60000 (100%)] 16: 0.255911 32: 0.206165 64: 0.160168
# Test set:
# 16: loss: 0.2460
# 32: loss: 0.1952
# 64: loss: 0.1489
#
# Train Epoch: 15 [00000/60000 (0%)] 16: 0.242762 32: 0.196945 64: 0.154157
# Train Epoch: 15 [30000/60000 (50%)] 16: 0.244530 32: 0.186662 64: 0.136285
# Train Epoch: 15 [60000/60000 (100%)] 16: 0.246956 32: 0.195374 64: 0.153111
# Test set:
# 16: loss: 0.2415
# 32: loss: 0.1874
# 64: loss: 0.1417
#
# Train Epoch: 16 [00000/60000 (0%)] 16: 0.240558 32: 0.188195 64: 0.143858
# Train Epoch: 16 [30000/60000 (50%)] 16: 0.248736 32: 0.212022 64: 0.190075
# Train Epoch: 16 [60000/60000 (100%)] 16: 0.235908 32: 0.178223 64: 0.128479
# Test set:
# 16: loss: 0.2381
# 32: loss: 0.1836
# 64: loss: 0.1407
#
# Train Epoch: 17 [00000/60000 (0%)] 16: 0.237988 32: 0.177485 64: 0.127549
# Train Epoch: 17 [30000/60000 (50%)] 16: 0.238450 32: 0.185558 64: 0.143271
# Train Epoch: 17 [60000/60000 (100%)] 16: 0.233436 32: 0.197062 64: 0.171750
# Test set:
# 16: loss: 0.2342
# 32: loss: 0.1786
# 64: loss: 0.1368
#
# Train Epoch: 18 [00000/60000 (0%)] 16: 0.228584 32: 0.170759 64: 0.123995
# Train Epoch: 18 [30000/60000 (50%)] 16: 0.242720 32: 0.205408 64: 0.182751
# Train Epoch: 18 [60000/60000 (100%)] 16: 0.220520 32: 0.160574 64: 0.113444
# Test set:
# 16: loss: 0.2287
# 32: loss: 0.1714
# 64: loss: 0.1300
#
# Train Epoch: 19 [00000/60000 (0%)] 16: 0.223995 32: 0.162915 64: 0.116587
# Train Epoch: 19 [30000/60000 (50%)] 16: 0.221767 32: 0.158227 64: 0.112636
# Train Epoch: 19 [60000/60000 (100%)] 16: 0.218513 32: 0.158489 64: 0.112660
# Test set:
# 16: loss: 0.2251
# 32: loss: 0.1694
# 64: loss: 0.1300
#
# Train Epoch: 20 [00000/60000 (0%)] 16: 0.224414 32: 0.167650 64: 0.126954
# Train Epoch: 20 [30000/60000 (50%)] 16: 0.225003 32: 0.172348 64: 0.135931
# Train Epoch: 20 [60000/60000 (100%)] 16: 0.213647 32: 0.152904 64: 0.107081
# Test set:
# 16: loss: 0.2195
# 32: loss: 0.1644
# 64: loss: 0.1256

# %%
data, _ = next(iter(test_loader))
noized = add_noise(data, elementwise=True)
output = models['64'](noized[:50])
to_plot = output.view(-1, 1, 28, 28).data.numpy()

# %%
plot_mnist(data.data.numpy()[:50], (5, 10))
plot_mnist(noized[:50], (5, 10))
plot_mnist(to_plot, (5, 10))
